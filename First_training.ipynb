# %% [markdown]
# <a href="https://colab.research.google.com/github/jdre1/Machine-Learning-Bootcamp/blob/main/First_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import urllib3
import os
import seaborn as sns
import plotly as pt
import bokeh as bkh

# %%
data = {
    'size': ['XL', 'L', 'M', 'L', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red'],
    'gender': ['female', 'male', 'male', 'female', 'female'],
    'price': [199.0, 89.0, 99.0, 129.0, 79.0],
    'weight': [500, 450, 300, 380, 410],
    'bought': ['yes', 'no', 'yes', 'no', 'yes']
}

df_raw = pd.DataFrame(data=data)
df_raw
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
df = df_raw.copy()
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      object
#  1   color   5 non-null      object
#  2   gender  5 non-null      object
#  3   price   5 non-null      float64
#  4   weight  5 non-null      int64
#  5   bought  5 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 368.0+ bytes

# %%
df.describe().T
# Out:
#         count   mean        std    min    25%    50%    75%    max
# price     5.0  119.0  48.476799   79.0   89.0   99.0  129.0  199.0
# weight    5.0  408.0  75.299402  300.0  380.0  410.0  450.0  500.0

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0     450     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
for col in ['size', 'color', 'gender', 'bought']:
  df[col] = df[col].astype('category')
df['weight'] = df['weight'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      category
#  1   color   5 non-null      category
#  2   gender  5 non-null      category
#  3   price   5 non-null      float64
#  4   weight  5 non-null      float64
#  5   bought  5 non-null      category
# dtypes: category(4), float64(2)
# memory usage: 740.0 bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      category
#  1   color   5 non-null      category
#  2   gender  5 non-null      category
#  3   price   5 non-null      float64
#  4   weight  5 non-null      float64
#  5   bought  5 non-null      category
# dtypes: category(4), float64(2)
# memory usage: 740.0 bytes

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue    male   99.0   300.0    yes
# 3    L  green  female  129.0   380.0     no
# 4    M    red  female   79.0   410.0    yes

# %%
df.describe(include=['category']).T
# Out:
#        count unique     top freq
# size       5      3       L    2
# color      5      3   green    2
# gender     5      2  female    3
# bought     5      2     yes    3

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue    male   99.0   300.0    yes
# 3    L  green  female  129.0   380.0     no
# 4    M    red  female   79.0   410.0    yes

# %% [markdown]
# ###### Przygotowanie danych do klasyfikacji LabelEncoder służy do binaryzowania zmiennej objaśnianej - TARGET

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit_transform(df['bought'])
# Out:
# array([1, 0, 1, 0, 1])

# %%
df['bought'] = le.fit_transform(df['bought'])
df
# Out:
#   size  color  gender  price  weight  bought
# 0   XL    red  female  199.0   500.0       1
# 1    L  green    male   89.0   450.0       0
# 2    M   blue    male   99.0   300.0       1
# 3    L  green  female  129.0   380.0       0
# 4    M    red  female   79.0   410.0       1

# %% [markdown]
# ##### Przygotowanie danych do klasyfikacji OneHotEncoder służy do binaryzowania zmiennych objaśniających

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(drop='first', sparse=False)

# %%
#for col in ['size', 'color', 'gender']:
#  df[col] = encoder.fit(df[[col]])
#  df[col] = encoder.transform(df[[col]])
#df

# %%
encoder.fit(df[['size']])
mat = encoder.transform(df[['size']])
mat
# Out:
# array([[0., 1.],
#        [0., 0.],
#        [1., 0.],
#        [0., 0.],
#        [1., 0.]])

# %% [markdown]
# ##### Funkcja get dummies załatwia wszytko za jednym razem musiemy jednakże pamiętać o drop_first = True !!!

# %%
df_anal = pd.get_dummies(data = df_raw, drop_first='True')
df_anal
# Out:
#    price  weight  size_M  size_XL  color_green  color_red  gender_male  \
# 0  199.0     500       0        1            0          1            0
# 1   89.0     450       0        0            1          0            1
# 2   99.0     300       1        0            0          0            1
# 3  129.0     380       0        0            1          0            0
# 4   79.0     410       1        0            0          1            0
#
#    bought_yes
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1

# %% [markdown]
# ##### Skalowanie danych w bibliotece pandas std() jest estymatorem nie obciązonym

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()
df_anal[['price', 'weight']] = scalar.fit_transform(df_anal[['price','weight']])
df_new = df_anal.copy()

# %%
df_new
# Out:
#       price    weight  size_M  size_XL  color_green  color_red  gender_male  \
# 0  1.845062  1.366002       0        1            0          1            0
# 1 -0.691898  0.623610       0        0            1          0            1
# 2 -0.461266 -1.603567       1        0            0          0            1
# 3  0.230633 -0.415740       0        0            1          0            0
# 4 -0.922531  0.029696       1        0            0          1            0
#
#    bought_yes
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1
